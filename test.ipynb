# %%
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

with fits.open('/home/jovyan/test_darks/Preview_20240312_101731_dark60_bin1.fit') as f:
    print(f.info())
    image_data = f[0].data
# Out:
# Filename: /home/jovyan/test_darks/Preview_20240312_101731_dark60_bin1.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      32   (1304, 976)   int16 (rescales to uint16)
# None

# %%
plt.imshow(image_data, cmap='Greys',vmin=2200, vmax=2300)#norm=LogNorm()
plt.colorbar();

# %%
print('Min:', np.min(image_data))
print('Max:', np.max(image_data))
print('Mean:', np.mean(image_data))
print('Stdev:', np.std(image_data))
# Out:
# Min: 2176
# Max: 51232
# Mean: 2281.648383284723
# Stdev: 64.542944876112

# %%
from ccdproc import ImageFileCollection,combine
im_collection = ImageFileCollection('/home/jovyan/test_darks/')

# %%
im_collection.summary['file','imgtype']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_9697/2407433391.py in <cell line: 1>()
# ----> 1 im_collection.summary['file','imgtype']
#
# /opt/conda/lib/python3.9/site-packages/astropy/table/table.py in __getitem__(self, item)
#    2068         elif self._is_list_or_tuple_of_str(item):
#    2069             out = self.__class__(
# -> 2070                 [self[x] for x in item], copy_indices=self._copy_indices
#    2071             )
#    2072             out._groups = groups.TableGroups(
#
# /opt/conda/lib/python3.9/site-packages/astropy/table/table.py in <listcomp>(.0)
#    2068         elif self._is_list_or_tuple_of_str(item):
#    2069             out = self.__class__(
# -> 2070                 [self[x] for x in item], copy_indices=self._copy_indices
#    2071             )
#    2072             out._groups = groups.TableGroups(
#
# ...

# %%
with fits.open('/home/jovyan/calibrated/combined_bias.fit') as f:
    image_data2 = f[0].data

# %%
plt.imshow(image_data2, cmap='Greys',vmin=1990, vmax=2000)#norm=LogNorm()
plt.colorbar();

# %%
histogram = plt.hist(image_data.flatten(), bins='auto')
# Out:
# Error in callback <function flush_figures at 0xffff535679d0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/conda/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     124             # ignore the tracking, just draw and close all figures
#     125             try:
# --> 126                 return show(True)
#     127             except Exception as e:
#     128                 # safely show traceback if in IPython, else raise
#
# /opt/conda/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...
